# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv("train.csv")

# %%
test_data = pd.read_csv("test.csv")

# %%
oil_data = pd.read_csv("oil.csv")

# %%
holidays_data = pd.read_csv("holidays_events.csv")

# %%
store_data = pd.read_csv("stores.csv")

# %%
train_data
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# ...

# %%
train_data['date']=pd.to_datetime(train_data['date'],format='%Y-%m-%d')
train_data
# Out:
#               id       date  store_nbr                      family     sales  \
# 0              0 2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1 2013-01-01          1                   BABY CARE     0.000
# 2              2 2013-01-01          1                      BEAUTY     0.000
# 3              3 2013-01-01          1                   BEVERAGES     0.000
# 4              4 2013-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 3000883  3000883 2017-08-15          9                     POULTRY   438.133
# 3000884  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885 2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# 0                  0
# ...

# %%
test_data
# Out:
#             id        date  store_nbr                      family  onpromotion
# 0      3000888  2017-08-16          1                  AUTOMOTIVE            0
# 1      3000889  2017-08-16          1                   BABY CARE            0
# 2      3000890  2017-08-16          1                      BEAUTY            2
# 3      3000891  2017-08-16          1                   BEVERAGES           20
# 4      3000892  2017-08-16          1                       BOOKS            0
# ...        ...         ...        ...                         ...          ...
# 28507  3029395  2017-08-31          9                     POULTRY            1
# 28508  3029396  2017-08-31          9              PREPARED FOODS            0
# 28509  3029397  2017-08-31          9                     PRODUCE            1
# 28510  3029398  2017-08-31          9  SCHOOL AND OFFICE SUPPLIES            9
# 28511  3029399  2017-08-31          9                     SEAFOOD            0
#
# ...

# %%
oil_data
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
holidays_data
# Out:
#            date        type    locale locale_name  \
# 0    2012-03-02     Holiday     Local       Manta
# 1    2012-04-01     Holiday  Regional    Cotopaxi
# 2    2012-04-12     Holiday     Local      Cuenca
# 3    2012-04-14     Holiday     Local    Libertad
# 4    2012-04-21     Holiday     Local    Riobamba
# ..          ...         ...       ...         ...
# 345  2017-12-22  Additional  National     Ecuador
# 346  2017-12-23  Additional  National     Ecuador
# 347  2017-12-24  Additional  National     Ecuador
# 348  2017-12-25     Holiday  National     Ecuador
# 349  2017-12-26  Additional  National     Ecuador
#
#                        description  transferred
# 0               Fundacion de Manta        False
# 1    Provincializacion de Cotopaxi        False
# 2              Fundacion de Cuenca        False
# 3        Cantonizacion de Libertad        False
# 4        Cantonizacion de Riobamba        False
# ..                             ...          ...
# ...

# %%
holidays_data['date']=pd.to_datetime(holidays_data['date'],format='%Y-%m-%d')
holidays_data
# Out:
#           date        type    locale locale_name  \
# 0   2012-03-02     Holiday     Local       Manta
# 1   2012-04-01     Holiday  Regional    Cotopaxi
# 2   2012-04-12     Holiday     Local      Cuenca
# 3   2012-04-14     Holiday     Local    Libertad
# 4   2012-04-21     Holiday     Local    Riobamba
# ..         ...         ...       ...         ...
# 345 2017-12-22  Additional  National     Ecuador
# 346 2017-12-23  Additional  National     Ecuador
# 347 2017-12-24  Additional  National     Ecuador
# 348 2017-12-25     Holiday  National     Ecuador
# 349 2017-12-26  Additional  National     Ecuador
#
#                        description  transferred
# 0               Fundacion de Manta        False
# 1    Provincializacion de Cotopaxi        False
# 2              Fundacion de Cuenca        False
# 3        Cantonizacion de Libertad        False
# 4        Cantonizacion de Riobamba        False
# ..                             ...          ...
# ...

# %%
holidays_data['type'].value_counts()
# Out:
# type
# Holiday       221
# Event          56
# Additional     51
# Transfer       12
# Bridge          5
# Work Day        5
# Name: count, dtype: int64

# %%
store_data
# Out:
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# ...

# %%
oil_data
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %% [markdown]
# Here we can see in oil_data the datatype of column date is not in datetime format. So we need to convert it from object to datetime

# %%
import time
import datetime

# %%
oil_data = pd.read_csv("oil.csv")

# %%
oil_data
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil_data['date']=pd.to_datetime(oil_data['date'],format='%Y-%m-%d')
oil_data
# Out:
#            date  dcoilwtico
# 0    2013-01-01         NaN
# 1    2013-01-02       93.14
# 2    2013-01-03       92.97
# 3    2013-01-04       93.12
# 4    2013-01-07       93.20
# ...         ...         ...
# 1213 2017-08-25       47.65
# 1214 2017-08-28       46.40
# 1215 2017-08-29       46.46
# 1216 2017-08-30       45.96
# 1217 2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
print(oil_data['date'].dtypes)
# Out:
# datetime64[ns]

# %%
oil_data['dcoilwtico'].plot(figsize = (20,8))
# Out:
# <Axes: >

# %% [markdown]
# We can clearly see from here that there are some missing values. So we need to fill the missing values

# %% [markdown]
# ### Filling Missing Values using Linear Interpolation

# %%
oil_data['dcoilwtico'] = oil_data['dcoilwtico'].fillna(method='bfill').interpolate(method = 'linear')

# %%
oil_data['dcoilwtico'].plot(figsize = (20,8))
# Out:
# <Axes: >

# %%
oil_data
# Out:
#            date  dcoilwtico
# 0    2013-01-01       93.14
# 1    2013-01-02       93.14
# 2    2013-01-03       92.97
# 3    2013-01-04       93.12
# 4    2013-01-07       93.20
# ...         ...         ...
# 1213 2017-08-25       47.65
# 1214 2017-08-28       46.40
# 1215 2017-08-29       46.46
# 1216 2017-08-30       45.96
# 1217 2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   datetime64[ns]
#  1   dcoilwtico  1218 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 19.2 KB

# %% [markdown]
# ## Merge data

# %%
df_merged = train_data.merge(holidays_data, on="date", how='outer').merge(store_data, on="store_nbr", how='outer').merge(oil_data, on="date", how='outer')

# %%
df_merged
# Out:
#           id       date  store_nbr      family  sales  onpromotion   type_x  \
# 0        0.0 2013-01-01        1.0  AUTOMOTIVE    0.0          0.0  Holiday
# 1        1.0 2013-01-01        1.0   BABY CARE    0.0          0.0  Holiday
# 2        2.0 2013-01-01        1.0      BEAUTY    0.0          0.0  Holiday
# 3        3.0 2013-01-01        1.0   BEVERAGES    0.0          0.0  Holiday
# 4        4.0 2013-01-01        1.0       BOOKS    0.0          0.0  Holiday
# ...      ...        ...        ...         ...    ...          ...      ...
# 3054422  NaN 2017-08-25        NaN         NaN    NaN          NaN      NaN
# 3054423  NaN 2017-08-28        NaN         NaN    NaN          NaN      NaN
# 3054424  NaN 2017-08-29        NaN         NaN    NaN          NaN      NaN
# 3054425  NaN 2017-08-30        NaN         NaN    NaN          NaN      NaN
# 3054426  NaN 2017-08-31        NaN         NaN    NaN          NaN      NaN
#
# ...

# %%
df_merged['sales'].plot(figsize = (20,8))
# Out:
# <Axes: >

# %% [markdown]
# # 2. Feature Engineering

# %% [markdown]
# ## Time-based Features :

# %%
df_merged = df_merged.drop(['id'], axis = 1)

# %%
df = df_merged.copy()
df
# Out:
#               date  store_nbr      family  sales  onpromotion   type_x  \
# 0       2013-01-01        1.0  AUTOMOTIVE    0.0          0.0  Holiday
# 1       2013-01-01        1.0   BABY CARE    0.0          0.0  Holiday
# 2       2013-01-01        1.0      BEAUTY    0.0          0.0  Holiday
# 3       2013-01-01        1.0   BEVERAGES    0.0          0.0  Holiday
# 4       2013-01-01        1.0       BOOKS    0.0          0.0  Holiday
# ...            ...        ...         ...    ...          ...      ...
# 3054422 2017-08-25        NaN         NaN    NaN          NaN      NaN
# 3054423 2017-08-28        NaN         NaN    NaN          NaN      NaN
# 3054424 2017-08-29        NaN         NaN    NaN          NaN      NaN
# 3054425 2017-08-30        NaN         NaN    NaN          NaN      NaN
# 3054426 2017-08-31        NaN         NaN    NaN          NaN      NaN
#
#            locale locale_name         description transferred   city  \
# ...

# %%
df['day'] = df['date'].dt.day
df['week'] = df['date'].dt.isocalendar().week
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year
df['week_day'] = df['date'].dt.day_name()

# %%
# Group by month and sum sales
monthly_sales = df.groupby(['year', 'month'])['sales'].sum().reset_index()

# Pivot table for better visualization
monthly_sales_pivot = monthly_sales.pivot(index='month', columns='year', values='sales')

# Plot monthly sales trends
plt.figure(figsize=(12, 6))
monthly_sales_pivot.plot(marker='o', cmap='coolwarm', figsize=(12, 6))
plt.title("Monthly Sales Trends Over the Years")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title="Year")
plt.grid()
plt.show()

# %% [markdown]
# ### Here we can clearly notice that overall sales increased in every year. Especially in December month there is a growth in sales every year respect to the other months.

# %% [markdown]
# ## Event-based Features :

# %%
df['type_x'].value_counts()
# Out:
# type_x
# Holiday       304772
# Event          99792
# Additional     67729
# Transfer       16041
# Work Day        8910
# Bridge          5348
# Name: count, dtype: int64

# %%
df['holiday'] = df['type_x'].apply(lambda x : 0 if x == 'Holiday' else 1)

# %%
df['holiday'].value_counts()
# Out:
# holiday
# 1    2749655
# 0     304772
# Name: count, dtype: int64

# %%
df['promotion'] = df['onpromotion'].apply(lambda x : 0 if x == 0 else 1)

# %%
df['is_payday'] = df['date'].apply(lambda x: 1 if x.day == 15 or x.day == x.days_in_month else 0)

# %%
df['earthquake_impact'] = df['date'].apply(lambda x: 1 if x == pd.Timestamp('2016-04-16') else 0)

# %%
df
# Out:
#               date  store_nbr      family  sales  onpromotion   type_x  \
# 0       2013-01-01        1.0  AUTOMOTIVE    0.0          0.0  Holiday
# 1       2013-01-01        1.0   BABY CARE    0.0          0.0  Holiday
# 2       2013-01-01        1.0      BEAUTY    0.0          0.0  Holiday
# 3       2013-01-01        1.0   BEVERAGES    0.0          0.0  Holiday
# 4       2013-01-01        1.0       BOOKS    0.0          0.0  Holiday
# ...            ...        ...         ...    ...          ...      ...
# 3054422 2017-08-25        NaN         NaN    NaN          NaN      NaN
# 3054423 2017-08-28        NaN         NaN    NaN          NaN      NaN
# 3054424 2017-08-29        NaN         NaN    NaN          NaN      NaN
# 3054425 2017-08-30        NaN         NaN    NaN          NaN      NaN
# 3054426 2017-08-31        NaN         NaN    NaN          NaN      NaN
#
#            locale locale_name         description transferred  ... dcoilwtico  \
# ...

# %% [markdown]
# ## Rolling Statistics :

# %%
df['MA_7'] = df['sales'].rolling(window=7).mean()   # 7-day Moving Average
df['MA_30'] = df['sales'].rolling(window=30).mean()  # 30-day Moving Average

df['STD_7'] = df['sales'].rolling(window=7).std()   # 7-day Rolling Standard Deviation
df['STD_30'] = df['sales'].rolling(window=30).std()  # 30-day Rolling Standard Deviation

# %% [markdown]
# ## Average Sales per Store

# %%
avg_sales_per_store_type = df.groupby('store_nbr')['sales'].mean().reset_index()

print(avg_sales_per_store_type)
# Out:
#     store_nbr        sales
# 0         1.0   254.651925
# 1         2.0   389.428979
# 2         3.0   911.098054
# 3         4.0   341.310288
# 4         5.0   281.184866
# 5         6.0   454.736152
# 6         7.0   485.565528
# 7         8.0   550.264615
# 8         9.0   476.819765
# 9        10.0   173.597978
# 10       11.0   511.059261
# 11       12.0   192.300469
# 12       13.0   189.718879
# 13       14.0   205.269313
# 14       15.0   206.267681
# 15       16.0   198.104822
# 16       17.0   325.591963
# 17       18.0   239.594719
# 18       19.0   235.352549
# 19       20.0   236.567080
# 20       21.0   168.098514
# 21       22.0    74.275130
# 22       23.0   210.141471
# 23       24.0   428.446546
# 24       25.0   206.050640
# 25       26.0   140.183026
# 26       27.0   346.571239
# 27       28.0   332.373163
# 28       29.0   176.398519
# 29       30.0   133.271473
# 30       31.0   320.714527
# 31       32.0   107.317900
# 32       33.0   255.849898
# ...

# %%
avg_sales_per_store_type['sales'].plot(figsize = (20,8), color = 'red', marker = 'o')
# Out:
# <Axes: >

# %% [markdown]
# ## Top Selling Product :

# %%
sales_per_family = df.groupby(['cluster', 'family'])['sales'].sum().reset_index()

# %%
sales_per_family
# Out:
#      cluster                      family         sales
# 0        1.0                  AUTOMOTIVE  1.759600e+04
# 1        1.0                   BABY CARE  1.930000e+02
# 2        1.0                      BEAUTY  1.859400e+04
# 3        1.0                   BEVERAGES  1.201252e+07
# 4        1.0                       BOOKS  4.600000e+02
# ..       ...                         ...           ...
# 556     17.0                     POULTRY  1.450990e+06
# 557     17.0              PREPARED FOODS  2.904738e+05
# 558     17.0                     PRODUCE  5.788314e+06
# 559     17.0  SCHOOL AND OFFICE SUPPLIES  1.074300e+04
# 560     17.0                     SEAFOOD  1.128698e+05
#
# [561 rows x 3 columns]

# %%
top_selling = sales_per_family.loc[sales_per_family.groupby('cluster')['sales'].idxmax()]

# %%
top_selling
# Out:
#      cluster     family         sales
# 12       1.0  GROCERY I  1.483284e+07
# 45       2.0  GROCERY I  8.649030e+06
# 78       3.0  GROCERY I  2.978610e+07
# 111      4.0  GROCERY I  1.682519e+07
# 144      5.0  GROCERY I  1.671595e+07
# 177      6.0  GROCERY I  4.397177e+07
# 210      7.0  GROCERY I  6.163853e+06
# 243      8.0  GROCERY I  2.768491e+07
# 276      9.0  GROCERY I  9.159591e+06
# 309     10.0  GROCERY I  3.021405e+07
# 342     11.0  GROCERY I  2.880349e+07
# 375     12.0  GROCERY I  6.589764e+06
# 408     13.0  GROCERY I  2.183388e+07
# 441     14.0  GROCERY I  5.394487e+07
# 474     15.0  GROCERY I  2.301842e+07
# 507     16.0  GROCERY I  4.228880e+06
# 540     17.0  GROCERY I  8.404701e+06

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(20, 9))
sns.lineplot(data = df, x ='date', y ='sales', color = 'b')

# Formatting
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales Trends Over Time')
plt.xticks(rotation = 45)
plt.grid(True)

# Show Plot
plt.show()

# %% [markdown]
# ## Analyze Sales in Holidays and Promotion :

# %%
holioday_sale = df.groupby('holiday')['sales'].sum().reset_index()
holioday_sale
# Out:
#    holiday         sales
# 0        0  1.092227e+08
# 1        1  9.873521e+08

# %%
promotion_sale = df.groupby('promotion')['sales'].sum().reset_index()
promotion_sale
# Out:
#    promotion         sales
# 0          0  3.832472e+08
# 1          1  7.133276e+08

# %%
plt.figure(figsize=(20, 8))


plt.subplot(1,2,1)
pp = sns.barplot(x = holioday_sale['holiday'], y = holioday_sale['sales'], palette='viridis')

plt.xlabel('Holiday (0 = Yes, 1 = NO)')
plt.ylabel('Sales')
plt.title('Sales Before and During Holidays')
plt.xticks([0, 1], ['Holiday', 'No Holiday'])

for i in pp.containers :
    pp.bar_label(i,)
    

plt.subplot(1,2,2)
pp = sns.barplot(x = promotion_sale['promotion'], y = promotion_sale['sales'], palette='viridis')

plt.xlabel('Holiday (0 = Yes, 1 = NO)')
plt.ylabel('Sales')
plt.title('Sales Before and During Promotion')
plt.xticks([0, 1], ['NO Promotion', 'Promotion'])

for i in pp.containers :
    pp.bar_label(i,)

# %% [markdown]
# #### we can notice over here during promotion sales increased

# %%
df.columns
# Out:
# Index(['date', 'store_nbr', 'family', 'sales', 'onpromotion', 'type_x',
#        'locale', 'locale_name', 'description', 'transferred', 'city', 'state',
#        'type_y', 'cluster', 'dcoilwtico', 'day', 'week', 'month', 'year',
#        'week_day', 'holiday', 'promotion', 'is_payday', 'earthquake_impact',
#        'MA_7', 'MA_30', 'STD_7', 'STD_30'],
#       dtype='object')

# %%
df.rename({'dcoilwtico' : 'oil_price'}, axis = 1, inplace = True)

# %%
correlation = df[['oil_price', 'sales']].corr()
print(correlation)
# Out:
#            oil_price     sales
# oil_price   1.000000 -0.079258
# sales      -0.079258  1.000000

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation between Oil Prices and Sales Trends")
plt.show()

# %%
plt.figure(figsize=(20, 9))
sns.lineplot(data = df, x ='date', y ='oil_price', color = 'b')

# Formatting
plt.xlabel('Date')
plt.ylabel('oil_price')
plt.title('oil price Trends Over Time')
plt.xticks(rotation = 45)
plt.grid(True)

# Show Plot
plt.show()

# %% [markdown]
# ####  After ploting  oil price values by years we noticed that in 2014 oil price suddenly decreased a lot. but comparing to the sales it increased slightly by years. And from the correlation also we can see that oil price didn't affet much on sales.

# %% [markdown]
# ####   Anomalies deduction :

# %%
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)  # First quartile (25%)
    Q3 = data[column].quantile(0.75)  # Third quartile (75%)
    IQR = Q3 - Q1  # Interquartile range
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] < lower_bound) | (data[column] > upper_bound)]

# %%
sales_anomalies = detect_outliers_iqr(df, 'sales')

# %%
sales_anomalies['sales']
# Out:
# 564         810.000
# 573         700.000
# 1785       1091.000
# 1789       1060.000
# 1790        579.000
#              ...
# 3054323     835.000
# 3054324     551.713
# 3054327    6630.383
# 3054340     522.000
# 3054345    2419.729
# Name: sales, Length: 455506, dtype: float64

# %%
df
# Out:
#               date  store_nbr      family  sales  onpromotion   type_x  \
# 0       2013-01-01        1.0  AUTOMOTIVE    0.0          0.0  Holiday
# 1       2013-01-01        1.0   BABY CARE    0.0          0.0  Holiday
# 2       2013-01-01        1.0      BEAUTY    0.0          0.0  Holiday
# 3       2013-01-01        1.0   BEVERAGES    0.0          0.0  Holiday
# 4       2013-01-01        1.0       BOOKS    0.0          0.0  Holiday
# ...            ...        ...         ...    ...          ...      ...
# 3054422 2017-08-25        NaN         NaN    NaN          NaN      NaN
# 3054423 2017-08-28        NaN         NaN    NaN          NaN      NaN
# 3054424 2017-08-29        NaN         NaN    NaN          NaN      NaN
# 3054425 2017-08-30        NaN         NaN    NaN          NaN      NaN
# 3054426 2017-08-31        NaN         NaN    NaN          NaN      NaN
#
#            locale locale_name         description transferred  ...  year  \
# ...

# %% [markdown]
# ## Model Training :

# %%
data = df.copy()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# ### Baseline Model (Naïve Forecasting)

# %%
data = data.sort_values(by='date')

# Apply Naïve Forecasting (shift previous sales value)
data['Naïve_Forecast'] = data['sales'].shift(1)

# Drop the first row since it has NaN forecast
data = data.dropna()


mae = mean_absolute_error(data['sales'], data['Naïve_Forecast'])
rmse = np.sqrt(mean_squared_error(data['sales'], data['Naïve_Forecast']))


print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
# Out:
# Mean Absolute Error (MAE): 582.22
# Root Mean Squared Error (RMSE): 1635.72

# %%
# Plot Actual vs. Naïve Forecast
plt.figure(figsize=(10,5))
plt.plot(data['date'], data['sales'], label="Actual Sales")
plt.plot(data['date'], data['Naïve_Forecast'], linestyle='dashed', label="Naïve Forecast", color='red')
plt.xlabel("Date")
plt.ylabel("Sales")
plt.title("Naïve Forecasting: Actual vs Forecasted Sales")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split

# %%
data = data.fillna(0)

# %%
data = data.set_index('date')
data
# Out:
#             store_nbr               family  sales  onpromotion   type_x  \
# date
# 2013-01-01       42.0         FROZEN FOODS    0.0          0.0  Holiday
# 2013-01-01       42.0            GROCERY I    0.0          0.0  Holiday
# 2013-01-01       42.0           GROCERY II    0.0          0.0  Holiday
# 2013-01-01       42.0             HARDWARE    0.0          0.0  Holiday
# 2013-01-01       42.0           LADIESWEAR    0.0          0.0  Holiday
# ...               ...                  ...    ...          ...      ...
# 2017-08-15       26.0             HARDWARE    0.0          0.0  Holiday
# 2017-08-15       26.0   HOME AND KITCHEN I   12.0          1.0  Holiday
# 2017-08-15       26.0  HOME AND KITCHEN II    6.0          0.0  Holiday
# 2017-08-15       26.0      HOME APPLIANCES    0.0          0.0  Holiday
# 2017-08-15       26.0           GROCERY II    3.0          0.0  Holiday
#
#               locale locale_name            description  transferred  \
# date
# ...

# %%
X = data[['MA_7','MA_30','STD_7','STD_30']]
y = data['sales']

# %%
# Train-Test Split (80% Train, 20% Test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = rf_model.predict(X_test)

# %%
# Evaluate Model Performance
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
# Out:
# Mean Absolute Error (MAE): 505.46
# Root Mean Squared Error (RMSE): 1200.49

# %%
# Plot Actual vs Predicted Sales
plt.figure(figsize=(10,5))
plt.plot(y_test.index, y_test, label="Actual Sales", marker='o')
plt.plot(y_test.index, y_pred, label="Random Forest Prediction", linestyle="dashed", color="red")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.title("Random Forest Forecasting")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### ARIMA (AutoRegressive Integrated Moving Average)

# %%
# !pip install pmdarima
# Out:
# Defaulting to user installation because normal site-packages is not writeable
#   WARNING: The scripts cygdb.exe, cython.exe and cythonize.exe are installed in 'C:\Users\Pritam Paul\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# ...
#   Obtaining dependency information for pmdarima from https://files.pythonhosted.org/packages/ac/f8/6c9364602b13f0dba129b53acd1344859690911a4d5021560d9fd6aa087f/pmdarima-2.0.4-cp311-cp311-win_amd64.whl.metadata
# ...

# %%
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from pmdarima import auto_arima

# %%
# Ensure data is sorted by Date
data = data.sort_index()

# Visualize the Sales Data
plt.figure(figsize=(10,5))
plt.plot(data.index, data['sales'], label="Sales Data")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.title("Sales Data Over Time")
plt.legend()
plt.show()

# %%
# Check Stationarity using ADF Test
def adf_test(series):
    result = adfuller(series)
    print("ADF Statistic:", result[0])
    print("p-value:", result[1])
    if result[1] <= 0.05:
        print("Data is stationary")
    else:
        print("Data is NOT stationary (Needs Differencing)")

adf_test(data['sales'])
# Out:
# ADF Statistic: -37.53187648726458
# p-value: 0.0
# Data is stationary

# %%
# Differencing (if needed)
data['Sales_diff'] = data['sales'].diff().dropna()

# Plot ACF & PACF to determine p and q
fig, ax = plt.subplots(1, 2, figsize=(12,5))
plot_acf(data['Sales_diff'].dropna(), ax=ax[0])
plot_pacf(data['Sales_diff'].dropna(), ax=ax[1])
plt.show()

# Auto ARIMA to find best (p, d, q)
auto_arima_model = auto_arima(data['sales'], seasonal=False, trace=True)
print(auto_arima_model.summary())

# Fit ARIMA model with best (p, d, q) values
p, d, q = auto_arima_model.order
arima_model = sm.tsa.ARIMA(data['sales'], order=(p, d, q))
arima_result = arima_model.fit()

# %%
# Forecast future values
forecast_steps = 10  # Adjust as needed
forecast = arima_result.forecast(steps=forecast_steps)

# %%
# Plot Actual vs Forecast
plt.figure(figsize=(10,5))
plt.plot(df.index, df['Sales'], label="Actual Sales")
plt.plot(pd.date_range(df.index[-1], periods=forecast_steps+1, freq='D')[1:], forecast, label="ARIMA Forecast", linestyle="dashed", color="red")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.title("ARIMA Forecasting")
plt.legend()
plt.show()

# Calculate MAE and RMSE
mae = mean_absolute_error(df['Sales'][-forecast_steps:], forecast[:forecast_steps])
rmse = np.sqrt(mean_squared_error(df['Sales'][-forecast_steps:], forecast[:forecast_steps]))
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
